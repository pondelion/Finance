# %%
import sys
import pandas as pd
import numpy as np

# %%
sys.path.append('../lib')
from agent import Agent
from market import Market
from model.conv import Conv
# %load_ext autoreload
# %autoreload 2
# Out:
# c:\users\user\appdata\local\programs\python\python35\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### BTC_USDデータの読み込み

# %%
pdf_btcusd = pd.read_csv('../data/bitmex/BTCUSD/chart_1hour.csv')

# %%
pdf_btcusd.head()
# Out:
#    Unnamed: 0  level_0                index   close    high     low    open  \
# 0           0       49  2018-07-17 07:00:00  6669.0  6683.0  6654.0  6663.5
# 1           1       48  2018-07-17 06:00:00  6663.5  6667.5  6642.5  6660.0
# 2           2       47  2018-07-17 05:00:00  6660.0  6678.0  6656.0  6675.0
# 3           3       46  2018-07-17 04:00:00  6675.0  6684.0  6633.5  6666.0
# 4           4       45  2018-07-17 03:00:00  6666.0  6697.0  6661.0  6668.0
#
#     s             t            v
# 0  ok  1.531778e+09   87418075.0
# 1  ok  1.531775e+09   44113455.0
# 2  ok  1.531771e+09   49454682.0
# 3  ok  1.531768e+09   98226041.0
# 4  ok  1.531764e+09  114057471.0

# %%
len(pdf_btcusd)
# Out:
# 15000

# %%
pdf_btcusd['index'] = pd.to_datetime(pdf_btcusd['index'])

# %%
# 日時でソート
pdf_btcusd = pdf_btcusd.sort_values('index')
pdf_btcusd = pdf_btcusd.reset_index(drop=True)

# %%
pdf_btcusd.head()
# Out:
#    Unnamed: 0  level_0               index   close    high     low    open  \
# 0       14999        0 2016-10-30 08:00:00  708.79  715.59  685.66  715.50
# 1       14998        1 2016-10-30 09:00:00  703.51  709.69  700.57  708.79
# 2       14997        2 2016-10-30 10:00:00  692.36  704.34  686.50  703.51
# 3       14996        3 2016-10-30 11:00:00  700.65  700.65  692.25  692.36
# 4       14995        4 2016-10-30 12:00:00  702.12  703.00  699.71  700.65
#
#     s             t          v
# 0  ok  1.477782e+09   664883.0
# 1  ok  1.477786e+09  1076548.0
# 2  ok  1.477789e+09  2160003.0
# 3  ok  1.477793e+09   504622.0
# 4  ok  1.477796e+09    76242.0

# %%
N_EPISODES = 10
STATE_WINDOW = 30
TIMESERIES_DATA_NUM = 1  # 時系列データの数。今回は終値のみ
N_ACTIONS = 4  # ノーポジ時(仮想通貨保有していない)：ノーポジ継続/買い。非ノーポジ(仮想通貨保有)時：売り、保持
BATCH_SIZE = 8
LEARNING_RATE = 1e-4
DISCOUNT_FACTOR = 0.8
COST = 0.

# %% [markdown]
# #### モデルの初期化 (Conv)

# %%
model = Conv(state_shape=(STATE_WINDOW, TIMESERIES_DATA_NUM), n_actions=N_ACTIONS)

# %%
M = 16
LAYERS = 2
FILTER_NUM = [M]*LAYERS
FILTER_SIZE = [3] * len(FILTER_NUM)
USE_POOL = None
DILATION = None
DENSE_UNITS = [48,24]

# %%
model.build_model(
    filter_num=FILTER_NUM, 
    filter_size=FILTER_SIZE, 
    dense_units=DENSE_UNITS, 
    learning_rate=LEARNING_RATE, 
    dilation=DILATION, 
    use_pool=USE_POOL
)

# %%
model._model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 30, 1)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 28, 16)            64
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 14, 16)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 12, 16)            784
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 6, 16)             0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 96)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 48)                4656
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                1176
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 100
# =================================================================
# Total params: 6,780
# Trainable params: 6,780
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### エージェント初期化

# %%
agent = Agent(model, discount_factor=DISCOUNT_FACTOR, batch_size=BATCH_SIZE)

# %% [markdown]
# #### マーケット初期化

# %%
np.array(pdf_btcusd['close']).reshape(pdf_btcusd['close'].shape[0], 1).shape
# Out:
# (15000, 1)

# %%
market = Market(
    prices=np.array(pdf_btcusd['close']).reshape(pdf_btcusd['close'].shape[0], 1), 
    window=STATE_WINDOW, 
    model=model, 
    cost=COST
)

# %% [markdown]
# #### 学習

# %%
# %%time
actions_hist = []
cum_rewards_hist = []
assets_hist = []

for episode in range(N_EPISODES):
    
    t_idx = STATE_WINDOW
    
    cum_rewards = []
    prev_cum_rewards = 0.
    actions = []
    states = []
    assets = []
    done = False
    
    state, valid_actions = market.reset()
    print('episode : ', episode)
    #print('state : ', state)
    #print('valid_actions : ', valid_actions)
    
    while not done:
        if t_idx % 1000 == 0:
            print('t_idx : ', t_idx)
        
        # 現在の状態と有効アクションリストから次にとるアクションを取得
        action = agent.act(state, valid_actions)
        #print('action : ', action)
        # アクションを実行し次の状態へ
        next_state, reward, done, valid_actions, asset = market.step(action)
        
        cum_rewards.append(prev_cum_rewards+reward)
        prev_cum_rewards = cum_rewards[-1]
        actions.append(action)
        states.append(next_state)
        assets.append(asset)
        
        # 状態の保存と学習
        agent.remember(state, action, reward, next_state, done, valid_actions)
        agent.replay()
        
        state = next_state
        
        t_idx += 1
        
    actions_hist.append(actions)
    cum_rewards_hist.append(cum_rewards)
    assets_hist.append(assets)
# Out:
# episode :  0
# t_idx :  1000
# t_idx :  2000
# t_idx :  3000
# t_idx :  4000
# t_idx :  5000
# t_idx :  6000
# t_idx :  7000
# t_idx :  8000
# t_idx :  9000
# t_idx :  10000
# t_idx :  11000
# t_idx :  12000
# t_idx :  13000
# t_idx :  14000
# episode :  1
# t_idx :  1000
# t_idx :  2000
# t_idx :  3000
# t_idx :  4000
# t_idx :  5000
# t_idx :  6000
# t_idx :  7000
# t_idx :  8000
# t_idx :  9000
# t_idx :  10000
# t_idx :  11000
# t_idx :  12000
# t_idx :  13000
# t_idx :  14000
# episode :  2
# t_idx :  1000
# t_idx :  2000
# t_idx :  3000
# t_idx :  4000
# t_idx :  5000
# t_idx :  6000
# t_idx :  7000
# t_idx :  8000
# t_idx :  9000
# t_idx :  10000
# t_idx :  11000
# t_idx :  12000
# t_idx :  13000
# t_idx :  14000
# episode :  3
# t_idx :  1000
# t_idx :  2000
# t_idx :  3000
# t_idx :  4000
# t_idx :  5000
# t_idx :  6000
# t_idx :  7000
# t_idx :  8000
# t_idx :  9000
# t_idx :  10000
# t_idx :  11000
# t_idx :  12000
# t_idx :  13000
# t_idx :  14000
# episode :  4
# t_idx :  1000
# t_idx :  2000
# t_idx :  3000
# t_idx :  4000
# t_idx :  5000
# t_idx :  6000
# t_idx :  7000
# t_idx :  8000
# t_idx :  9000
# t_idx :  10000
# t_idx :  11000
# t_idx :  12000
# t_idx :  13000
# t_idx :  14000
# episode :  5
# t_idx :  1000
# t_idx :  2000
# t_idx :  3000
# t_idx :  4000
# t_idx :  5000
# t_idx :  6000
# t_idx :  7000
# t_idx :  8000
# t_idx :  9000
# t_idx :  10000
# t_idx :  11000
# t_idx :  12000
# t_idx :  13000
# t_idx :  14000
# episode :  6
# t_idx :  1000
# t_idx :  2000
# t_idx :  3000
# t_idx :  4000
# t_idx :  5000
# t_idx :  6000
# t_idx :  7000
# t_idx :  8000
# t_idx :  9000
# t_idx :  10000
# t_idx :  11000
# t_idx :  12000
# t_idx :  13000
# t_idx :  14000
# episode :  7
# t_idx :  1000
# t_idx :  2000
# t_idx :  3000
# t_idx :  4000
# t_idx :  5000
# t_idx :  6000
# t_idx :  7000
# t_idx :  8000
# t_idx :  9000
# t_idx :  10000
# t_idx :  11000
# t_idx :  12000
# t_idx :  13000
# t_idx :  14000
# episode :  8
# t_idx :  1000
# t_idx :  2000
# t_idx :  3000
# t_idx :  4000
# t_idx :  5000
# t_idx :  6000
# t_idx :  7000
# t_idx :  8000
# t_idx :  9000
# t_idx :  10000
# t_idx :  11000
# t_idx :  12000
# t_idx :  13000
# t_idx :  14000
# episode :  9
# t_idx :  1000
# t_idx :  2000
# t_idx :  3000
# t_idx :  4000
# t_idx :  5000
# t_idx :  6000
# t_idx :  7000
# t_idx :  8000
# t_idx :  9000
# t_idx :  10000
# t_idx :  11000
# t_idx :  12000
# t_idx :  13000
# t_idx :  14000
# Wall time: 42min 34s

# %%
import matplotlib.pyplot as plt
from pylab import rcParams

rcParams['figure.figsize'] = 14,8

# %%
# 総報酬の推移
plt.clf()
for i in range(len(cum_rewards_hist)):
    plt.plot(cum_rewards_hist[i], label='episode {}'.format(i))

plt.xlabel('time index')
plt.ylabel('cumulative reward')
plt.legend()
plt.show()

# %%
# アクションの遷移
plt.clf()
plt.plot(actions_hist[-1][:300])

# %%
# 総資産の推移
plt.clf()
for i in range(len(assets_hist)):
    plt.plot(assets_hist[i], label='episode {}'.format(i))

plt.xlabel('time index')
plt.ylabel('assets')
plt.legend()
plt.show()

# %% [markdown]
# #### モデルの保存

# %%
model.save(fld='../output/model/conv')
